# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import os
import matplotlib.pyplot as plt
import random
import psycopg2
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

#!pip install psycopg2-binary
# %reload_ext sql

# %%
bikeshare_data = pd.read_csv("202203-capitalbikeshare-tripdata.csv", parse_dates = ['started_at', 'ended_at'])

# %%
bikeshare_data.dtypes #Take a look at the data types
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id             float64
# end_station_name              object
# end_station_id               float64
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %% [markdown]
# #### Create database with the following code (Converted to markdown because only use once):
#
# conn = psycopg2.connect("user=postgres password='password'")
# conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT);
# cursor = conn.cursor();
# sqlCreateDatabase = "create database bikesharedb;"
# cursor.execute(sqlCreateDatabase);
# cursor.close();

# %%
'''
Create a sql_alchemy engine to import pandas dataframes into SQL database. I am using this instead of psycopg2 
in order to save time versus using psycopg2 and CREATE TABLE or INSERT syntax. I imported it directly using SQL 
'''
dbname = 'bikesharedb' 
username='postgres'
password='password'
host='localhost'
db_conn = f'postgresql+psycopg2://{username}:{password}@{host}/{dbname}'

# %% [markdown]
# #### Create Table (Converted to markdown because only use once.)
# table_name = 'bikeshare3'
#
# table = f'''CREATE TABLE {table_name} (
# ride_id INT PRIMARY KEY NOT NULL UNIQUE,
# rideable_type varchar(10),
# started_at timestamp,
# ended_at timestamp,
# start_station_name varchar(50),
# start_station_id  INT FOREIGN KEY NOT NULL,
# end_station_name  varchar(50),
# end_station_id INT FOREIGN KEY NOT NULL,
# start_lat REAL,
# start_lng REAL,
# end_lat   REAL ,
# end_lng   REAL,
# member_casual VARCHAR(15));
# '''
# conn = psycopg2.connect("user=postgres password='password'")
# db_cursor = conn.cursor()
# db_cursor.execute(table)
# conn.commit()
# db_cursor.close()
#
#
# db_cursor = conn.cursor()
# db_cursor.execute("COPY bikeshare3 FROM '202203-capitalbikeshare-tripdata.csv' WITH (FORMAT csv);")
# conn.commit()
# db_cursor.close()

# %%
engine = create_engine(f'{db_conn}', echo=False)

# %% [markdown]
# #### Other way to send data to sql (Converted to Markdown because only use once)
# bikeshare_data.to_sql('bikeshare3', con=engine, if_exists='replace', index=False)

# %%
df = pd.read_sql_query("SELECT * FROM bikeshare3 LIMIT 5;", engine) #can now read in Python
df
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  63DD0ABA5C512840  electric_bike 2022-03-29 18:55:57 2022-03-29 18:56:11
# 1  5258E72F8C5C66F3  electric_bike 2022-03-22 22:57:37 2022-03-22 23:16:33
# 2  54DBDFE5135510AB  electric_bike 2022-03-22 22:31:00 2022-03-22 22:33:39
# 3  90918421F47CA6C1  electric_bike 2022-03-22 22:26:13 2022-03-22 22:26:32
# 4  E49D00F1DAD8BE20    docked_bike 2022-03-25 14:05:43 2022-03-25 16:07:16
#
#        start_station_name  start_station_id end_station_name end_station_id  \
# 0                    None               NaN             None           None
# 1                    None               NaN             None           None
# 2                    None               NaN             None           None
# 3                    None               NaN             None           None
# 4  4th St & Madison Dr NW           31288.0             None           None
#
#    start_lat  start_lng  end_lat  end_lng member_casual  lat_change  \
# 0  38.900000 -77.040000    38.90   -77.04        member         0.0
# 1  38.800000 -77.040000    38.80   -77.04        casual         0.0
# 2  38.890000 -77.010000    38.89   -77.01        casual         0.0
# 3  38.890000 -77.010000    38.89   -77.01        casual         0.0
# 4  38.890496 -77.017247      NaN      NaN        casual         NaN
#
#    long_change        duration     b
# 0          0.0 0 days 00:00:14  None
# 1          0.0 0 days 00:18:56  None
# 2          0.0 0 days 00:02:39  None
# 3          0.0 0 days 00:00:19  None
# 4          NaN 0 days 02:01:33  None

# %%
df[df['ride_id'] == '5258E72F8C5C66F3']
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 1  5258E72F8C5C66F3  electric_bike 2022-03-22 22:57:37 2022-03-22 23:16:33
#
#   start_station_name  start_station_id end_station_name end_station_id  \
# 1               None               NaN             None           None
#
#    start_lat  start_lng  end_lat  end_lng member_casual  lat_change  \
# 1       38.8     -77.04     38.8   -77.04        casual         0.0
#
#    long_change        duration     b
# 1          0.0 0 days 00:18:56  None

# %% [markdown]
# #### How to add columns to a table (Converted to markdown because only use once
# q = '''
# ALTER TABLE bikeshare3 ADD COLUMN duration REAL;
# ALTER TABLE bikeshare3 ADD COLUMN lat_change REAL;
# ALTER TABLE bikeshare3 ADD COLUMN long_change REAL;
# '''
# conn = psycopg2.connect(f'dbname=bikesharedb user=postgres password=password')
# conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT);
# db_cursor = conn.cursor()
# db_cursor.execute(q)
# conn.commit()
# db_cursor.close()

# %%
df.dtypes #data types of columns. The columns I created above are now listed
# Out:
# ride_id                        object
# rideable_type                  object
# started_at             datetime64[ns]
# ended_at               datetime64[ns]
# start_station_name             object
# start_station_id              float64
# end_station_name               object
# end_station_id                 object
# start_lat                     float64
# start_lng                     float64
# end_lat                       float64
# end_lng                       float64
# member_casual                  object
# lat_change                    float64
# long_change                   float64
# duration              timedelta64[ns]
# b                              object
# dtype: object

# %%
# it works!
df = pd.read_sql_query("SELECT * FROM bikeshare3 LIMIT 5;", engine) #can now read in Python

# %%
df
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0                 1       testName                 NaT                 NaT
# 1  1F4FCB442E18DFAB  electric_bike 2022-03-19 14:20:15 2022-03-19 14:50:10
# 2  AD4FAF264C9EB1F2    docked_bike 2022-03-21 21:08:36 2022-03-30 10:00:12
# 3  70DD2688B58DE3AD  electric_bike 2022-03-20 20:53:02 2022-03-20 20:58:38
# 4  E5DB491266DC9F50  electric_bike 2022-03-07 17:40:54 2022-03-07 17:46:33
#
#               start_station_name  start_station_id end_station_name  \
# 0                           None               NaN             None
# 1                           None               NaN             None
# 2  21st St & Constitution Ave NW           31261.0             None
# 3                           None               NaN             None
# 4                           None               NaN             None
#
#   end_station_id  start_lat  start_lng  end_lat  end_lng member_casual  \
# 0           None        NaN        NaN      NaN      NaN          None
# 1           None  38.880000 -77.030000    38.88   -76.96        member
# 2           None  38.892459 -77.046567      NaN      NaN        casual
# 3           None  38.900000 -77.010000    38.90   -76.99        casual
# 4           None  38.880000 -77.020000    38.88   -77.00        member
#
#    lat_change  long_change        duration     b
# 0         NaN          NaN             NaT  None
# 1         0.0         0.07 0 days 00:29:55  None
# 2         NaN          NaN 8 days 12:51:36  None
# 3         0.0         0.02 0 days 00:05:36  None
# 4         0.0         0.02 0 days 00:05:39  None

# %% [markdown]
# #### Error handling
# I ran into an error because I designated the wrong type for duration above. It should be interval not real. Here I drop the column and then add it again as interval.

# %% [markdown]
# q = '''ALTER TABLE bikeshare3
# DROP COLUMN duration;'''
# conn = psycopg2.connect(f'dbname=bikesharedb user=postgres password=password')
# conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT);
# db_cursor = conn.cursor()
# db_cursor.execute(q)
# conn.commit()
# db_cursor.close()

# %% [markdown]
# q = '''ALTER TABLE bikeshare3 ADD COLUMN duration INTERVAL;'''
# conn = psycopg2.connect(f'dbname=bikesharedb user=postgres password=password')
# conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT);
# db_cursor = conn.cursor()
# db_cursor.execute(q)
# conn.commit()
# db_cursor.close()

# %% [markdown]
# #### Now that my columns are added, I need to add values. To do this, I use UPDATE...SET. But, if I needed to, I could also create a procedure to do the same thing which I will show you after.

# %% [markdown]
# q = '''
# UPDATE bikeshare3
# SET duration = CAST(ended_at AS TIMESTAMP) - CAST(started_at AS TIMESTAMP);
# UPDATE bikeshare3
# SET lat_change = end_lat - start_lat;
# UPDATE bikeshare3
# SET long_change = end_lng - start_lng;
# '''
#
# conn = psycopg2.connect(f'dbname=bikesharedb user=postgres password=password')
# conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT);
# db_cursor = conn.cursor()
# db_cursor.execute(q)
# conn.commit()
# db_cursor.close()

# %%
df = pd.read_sql_query("SELECT * FROM bikeshare3 LIMIT 5;", engine) #can now read in Python

# %%
df #success - Setting duration to interval allowed me to engineer a new variable containing the duration!
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  5C6B106A8F184F26  electric_bike 2022-03-14 16:57:58 2022-03-14 17:06:41
# 1  785A5820FB0919FB  electric_bike 2022-03-21 14:17:44 2022-03-21 14:23:56
# 2  9FBE184BFBD7403F   classic_bike 2022-03-06 11:03:30 2022-03-07 12:03:24
# 3  3AB2C3806C1AA363  electric_bike 2022-03-21 18:35:21 2022-03-21 18:36:15
# 4  97C48A6A3E7A7901  electric_bike 2022-03-21 18:12:44 2022-03-21 18:14:44
#
#   start_station_name  start_station_id end_station_name end_station_id  \
# 0      1st & O St NW           31519.0             None           None
# 1               None               NaN             None           None
# 2      6th & H St NE           31615.0             None           None
# 3               None               NaN             None           None
# 4               None               NaN             None           None
#
#    start_lat  start_lng  end_lat  end_lng member_casual  lat_change  \
# 0  38.908682 -77.012388    38.92   -77.03        casual    0.011318
# 1  38.920000 -77.050000    38.91   -77.06        casual   -0.010000
# 2  38.899972 -76.998347      NaN      NaN        casual         NaN
# 3  38.900000 -77.000000    38.90   -77.00        casual    0.000000
# 4  38.920000 -77.030000    38.92   -77.03        casual    0.000000
#
#    long_change        duration     b
# 0    -0.017612 0 days 00:08:43  None
# 1    -0.010000 0 days 00:06:12  None
# 2          NaN 1 days 00:59:54  None
# 3     0.000000 0 days 00:00:54  None
# 4     0.000000 0 days 00:02:00  None

# %% [markdown]
# #### I will use a procedure directly in PostgreSQL to set the column values to NULL
#
# CREATE OR REPLACE PROCEDURE public.update_procNULL()
# LANGUAGE sql
# DELIMITER //  #COMMENT: Two dollar signs, "$$" read as italics in markdown.
# AS /BODY/
#
#     UPDATE bikeshare3 SET duration = NULL;
#     UPDATE bikeshare3 SET lat_change = NULL;
#     UPDATE bikeshare3 SET long_change = NULL;
#
# /BODY/;
#
# CALL update_procNULL(); #COMMENT: Because it doesn't return anything, Jupyter Notebook returns an error. But, it works directly in PostgreSQL and much faster.

# %%
pd.read_sql_query('''SELECT * FROM bikeshare3 LIMIT 5;''', engine) #success
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  EB105273FFBDA87C   classic_bike 2022-03-07 15:58:52 2022-03-07 16:11:34
# 1  419C76008E40C45C   classic_bike 2022-03-17 06:49:14 2022-03-17 07:27:58
# 2  8E84C1E079CAD576  electric_bike 2022-03-04 12:21:29 2022-03-04 12:29:05
# 3  77E60E97D8376AF8  electric_bike 2022-03-18 07:16:23 2022-03-18 07:29:52
# 4  28C2EEA8B658B4F7   classic_bike 2022-03-28 15:36:57 2022-03-28 15:47:06
#
#               start_station_name  start_station_id  \
# 0                3rd & Elm St NW           31118.0
# 1  Mount Vernon Ave & Kennedy St           31088.0
# 2        Park Rd & Holmead Pl NW           31602.0
# 3                           None               NaN
# 4                 18th & R St NW           31278.0
#
#               end_station_name  end_station_id  start_lat  start_lng  \
# 0  18th & New Hampshire Ave NW         31324.0  38.917622 -77.015970
# 1      Lynn St & 19th St North         31014.0  38.833077 -77.059821
# 2  18th & New Hampshire Ave NW         31324.0  38.930785 -77.031095
# 3         Van Ness Metro / UDC         31300.0  38.940000 -77.040000
# 4               21st & I St NW         31205.0  38.912648 -77.041834
#
#      end_lat    end_lng member_casual lat_change long_change duration     b
# 0  38.911268 -77.041829        member       None        None     None  None
# 1  38.897315 -77.070993        casual       None        None     None  None
# 2  38.911268 -77.041829        casual       None        None     None  None
# 3  38.944551 -77.063896        casual       None        None     None  None
# 4  38.900711 -77.046449        member       None        None     None  None

# %% [markdown]
# #### Now I will use the following procedure to add values to these columns again.
# CREATE OR REPLACE PROCEDURE public.update_proc()
# LANGUAGE sql
# AS /BODY/
#
#     UPDATE bikeshare3 SET duration = CAST(ended_at AS TIMESTAMP) - CAST(started_at
#           AS TIMESTAMP);
#     UPDATE bikeshare3 SET lat_change = end_lat - start_lat;
#     UPDATE bikeshare3 SET long_change = end_lng - start_lng;
#
# /BODY/;
#
# CALL update_proc();

# %%
df = pd.read_sql_query('''SELECT * FROM bikeshare3 LIMIT 5''', engine); #We have values again!
df
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  AC74CC947C2E69DC   classic_bike 2022-03-15 19:26:34 2022-03-15 19:38:14
# 1  99B27B72B698AB3E  electric_bike 2022-03-30 08:59:08 2022-03-30 09:17:08
# 2  B55DBC06234F42D1   classic_bike 2022-03-14 09:08:41 2022-03-14 09:12:06
# 3  62F0FF83983A4D51   classic_bike 2022-03-15 19:17:53 2022-03-15 19:21:28
# 4  C423B92FD1D4AA74   classic_bike 2022-03-10 13:27:43 2022-03-10 13:48:23
#
#   start_station_name  start_station_id                   end_station_name  \
# 0     13th & E St SE           31607.0                      6th & H St NE
# 1               None               NaN                     15th & M St NW
# 2     12th & L St NW           31251.0  Convention Center / 7th & M St NW
# 3       Union Market           31517.0                      6th & H St NE
# 4     12th & L St NW           31251.0                      6th & H St NE
#
#    end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# 0         31615.0  38.882915 -76.987907  38.899972 -76.998347        member
# 1         31298.0  38.900000 -76.990000  38.905424 -77.034674        member
# 2         31223.0  38.903819 -77.028400  38.905737 -77.022270        member
# 3         31615.0  38.907908 -76.997070  38.899972 -76.998347        member
# 4         31615.0  38.903819 -77.028400  38.899972 -76.998347        casual
#
#    lat_change  long_change        duration     b
# 0    0.017057    -0.010440 0 days 00:11:40  None
# 1    0.005424    -0.044674 0 days 00:18:00  None
# 2    0.001918     0.006130 0 days 00:03:25  None
# 3   -0.007936    -0.001277 0 days 00:03:35  None
# 4   -0.003847     0.030053 0 days 00:20:40  None

# %% [markdown]
# # Need to clean some data
# It looks like there are some inaccurate data points. The end timestamp is before the start timestamp. We can drop these operations in the analysis but the data should be corrected at some time.

# %%
q = '''
SELECT ride_id, duration, started_at, ended_at, AVG(duration) OVER(PARTITION BY start_station_id) as avg_duration_by_start_station
FROM bikeshare3
ORDER BY duration
LIMIT 10
'''
df = pd.read_sql_query(q, engine) #can now read in Python
df
# Out:
#             ride_id          duration          started_at            ended_at  \
# 0  F22BBAD63223D8D5 -1 days +23:57:06 2022-03-10 17:55:01 2022-03-10 17:52:07
# 1  9FA4056C4B75F39C -1 days +23:57:29 2022-03-31 14:04:13 2022-03-31 14:01:42
# 2  4C1A26212690BA44 -1 days +23:58:16 2022-03-16 15:23:40 2022-03-16 15:21:56
# 3  46F938EC00EA932C -1 days +23:59:08 2022-03-28 16:51:45 2022-03-28 16:50:53
# 4  B1EBF9DBA20A26B4 -1 days +23:59:25 2022-03-25 16:30:50 2022-03-25 16:30:15
# 5  F8A94B9BEEA7BD07 -1 days +23:59:33 2022-03-26 15:45:50 2022-03-26 15:45:23
# 6  016FE89395F179C3 -1 days +23:59:56 2022-03-05 14:11:50 2022-03-05 14:11:46
# 7  3A0ECA9C06CEFF93   0 days 00:00:00 2022-03-14 07:53:50 2022-03-14 07:53:50
# 8  9B3A2B7C8B16483B   0 days 00:00:00 2022-03-06 04:47:26 2022-03-06 04:47:26
# 9  72D5ABB0C6F17B00   0 days 00:00:00 2022-03-21 14:52:57 2022-03-21 14:52:57
#
#   avg_duration_by_start_station
# 0        0 days 00:23:32.226757
# 1        0 days 00:46:53.148067
# 2        0 days 00:14:29.193152
# 3        0 days 00:16:10.480916
# 4        0 days 00:30:26.920319
# 5        0 days 00:34:31.729335
# 6        0 days 00:14:29.193152
# 7        0 days 00:18:53.563185
# 8        0 days 00:13:08.038674
# 9        0 days 00:39:16.318092

# %% [markdown]
# ##### ONLY PULL WHERE DURATION IS GREATER THAN OR EQUAL TO AN INTERVAL OF 0 DAYS 0 HOURS AND 0 MINUTES.

# %%
df = pd.read_sql_query('''SELECT * 
                            FROM bikeshare3 
                            WHERE duration >= CAST('0 days 00:00:00' AS INTERVAL) 
                            ORDER BY duration''', engine)
df
# Out:
#                  ride_id rideable_type          started_at  \
# 0       6EE723BC73517BC3  classic_bike 2022-03-22 18:43:28
# 1       8FD159FA30278F49  classic_bike 2022-03-25 15:04:16
# 2       29F300C29059C060  classic_bike 2022-03-21 15:41:50
# 3       3C6BB8B171D0118D  classic_bike 2022-03-31 07:35:58
# 4       9B49A8A88FEF86E0  classic_bike 2022-03-16 18:56:06
# ...                  ...           ...                 ...
# 254238  AD4FAF264C9EB1F2   docked_bike 2022-03-21 21:08:36
# 254239  4AED037983B838FD   docked_bike 2022-03-13 19:34:25
# 254240  5AE580CF557383BD   docked_bike 2022-03-05 16:50:11
# 254241  113BAF7ED46B30D8   docked_bike 2022-03-02 01:02:52
# 254242  8957FC45C76332F8   docked_bike 2022-03-13 19:34:26
#
#                   ended_at                   start_station_name  \
# 0      2022-03-22 18:43:28             New Jersey Ave & F St NW
# 1      2022-03-25 15:04:16  John McCormack Dr & Michigan Ave NE
# 2      2022-03-21 15:41:50                        3rd & D St SE
# 3      2022-03-31 07:35:58                        1st & K St SE
# 4      2022-03-16 18:56:06               4th St & Madison Dr NW
# ...                    ...                                  ...
# 254238 2022-03-30 10:00:12        21st St & Constitution Ave NW
# 254239 2022-03-22 11:49:09         7th & R St NW / Shaw Library
# 254240 2022-03-17 00:05:08                        8th & O St NW
# 254241 2022-03-17 11:39:56               Shady Grove Metro West
# 254242 2022-03-30 10:59:01         7th & R St NW / Shaw Library
#
#         start_station_id                     end_station_name  end_station_id  \
# 0                31655.0             New Jersey Ave & F St NW         31655.0
# 1                31502.0  John McCormack Dr & Michigan Ave NE         31502.0
# 2                31605.0                        3rd & D St SE         31605.0
# 3                31628.0                        1st & K St SE         31628.0
# 4                31288.0               4th St & Madison Dr NW         31288.0
# ...                  ...                                  ...             ...
# 254238           31261.0                                 None             NaN
# 254239           31245.0            Good Hope Rd & 14th St SE         31803.0
# 254240           31281.0                    14th & Otis Pl NW         31131.0
# 254241           32045.0          King Farm Blvd & Piccard Dr         32038.0
# 254242           31245.0                       6035 Warehouse         32901.0
#
#         start_lat  start_lng    end_lat    end_lng member_casual  lat_change  \
# 0       38.897108 -77.011616  38.897108 -77.011616        member    0.000000
# 1       38.934600 -76.995500  38.934600 -76.995500        casual    0.000000
# 2       38.885100 -77.002300  38.885100 -77.002300        member    0.000000
# 3       38.878854 -77.005727  38.878854 -77.005727        casual    0.000000
# 4       38.890496 -77.017246  38.890496 -77.017246        casual    0.000000
# ...           ...        ...        ...        ...           ...         ...
# 254238  38.892459 -77.046567        NaN        NaN        casual         NaN
# 254239  38.912719 -77.022155  38.866611 -76.985238        casual   -0.046108
# 254240  38.908640 -77.022770  38.934405 -77.032687        casual    0.025765
# 254241  39.119765 -77.166093  39.110314 -77.182669        casual   -0.009451
# 254242  38.912719 -77.022155  38.963810 -77.010266        casual    0.051091
#
#         long_change         duration     b
# 0          0.000000  0 days 00:00:00  None
# 1          0.000000  0 days 00:00:00  None
# 2          0.000000  0 days 00:00:00  None
# 3          0.000000  0 days 00:00:00  None
# 4          0.000000  0 days 00:00:00  None
# ...             ...              ...   ...
# 254238          NaN  8 days 12:51:36  None
# 254239     0.036917  8 days 16:14:44  None
# 254240    -0.009917 11 days 07:14:57  None
# 254241    -0.016576 15 days 10:37:04  None
# 254242     0.011889 16 days 15:24:35  None
#
# [254243 rows x 17 columns]

# %% [markdown]
# #### INCLUDE THE AVERAGE DURATION BY start_station_id

# %%
q = '''
SELECT ride_id, duration, started_at, ended_at, AVG(duration) OVER(PARTITION BY start_station_id) as avg_duration_by_start_station
FROM bikeshare3
WHERE duration > CAST('0 days 00:00:00' AS INTERVAL)
ORDER BY duration
LIMIT 10
'''
df = pd.read_sql_query(q, engine) #can now read in Python
df
# Out:
#             ride_id        duration          started_at            ended_at  \
# 0  DB0252F6CC9CD0D7 0 days 00:00:01 2022-03-01 16:14:23 2022-03-01 16:14:24
# 1  5F301BF38895BADA 0 days 00:00:01 2022-03-22 08:37:28 2022-03-22 08:37:29
# 2  5D1BE0FDA5B045FA 0 days 00:00:01 2022-03-25 08:26:57 2022-03-25 08:26:58
# 3  38B7C51E8488681E 0 days 00:00:01 2022-03-15 16:41:13 2022-03-15 16:41:14
# 4  5D387666D250DF61 0 days 00:00:01 2022-03-05 09:14:31 2022-03-05 09:14:32
# 5  A9E9B559B306BBAF 0 days 00:00:01 2022-03-10 10:00:21 2022-03-10 10:00:22
# 6  14E3256DA31FEC85 0 days 00:00:01 2022-03-19 13:44:19 2022-03-19 13:44:20
# 7  52708800AC284D57 0 days 00:00:01 2022-03-08 18:56:11 2022-03-08 18:56:12
# 8  B319418A657D9F4C 0 days 00:00:01 2022-03-14 20:51:05 2022-03-14 20:51:06
# 9  F614091DF6D4EF0E 0 days 00:00:01 2022-03-29 16:58:03 2022-03-29 16:58:04
#
#   avg_duration_by_start_station
# 0        0 days 00:12:40.368463
# 1        0 days 00:13:18.279595
# 2        0 days 00:17:29.470389
# 3        0 days 00:32:59.658742
# 4        0 days 00:15:59.699561
# 5        0 days 00:13:18.279595
# 6        0 days 00:22:04.564516
# 7        0 days 00:17:29.470389
# 8        0 days 00:20:16.961538
# 9        0 days 00:17:42.629268

# %% [markdown]
# We have three types of bikes that consumers can rent: classic_bike, docked_bike, and electric bike. The classic bike is the most popular rental followed by the electric bike and the docked_bike is the least popular rental. This could be due to inventory availability.

# %%
q =''' 
SELECT DISTINCT rideable_type, COUNT(rideable_type) as num_rentals
FROM bikeshare3
WHERE duration > CAST('0 days 00:00:00' AS INTERVAL)
GROUP BY rideable_type
'''
df = pd.read_sql_query(q, engine) 
df
# Out:
#    rideable_type  num_rentals
# 0   classic_bike       192329
# 1    docked_bike        19198
# 2  electric_bike        42688

# %% [markdown]
# The number of rentals per each station using a group by on start_station_id and an aggregate function in the select statement.

# %%
'''
SELECT start_station_id, COUNT(start_station_id) as num_rentals
FROM bikesharedb
WHERE duration > CAST('0 days 00:00:00' AS INTERVAL)
GROUP BY start_station_id
ORDER BY num_rentals DESC
LIMIT 10 '''
df = pd.read_sql_query(q, engine)
df
# Out:
#    rideable_type  num_rentals
# 0   classic_bike       192329
# 1    docked_bike        19198
# 2  electric_bike        42688

# %% [markdown]
# #### NUMBER OF RENTALS PER DAY

# %%
q = '''
SELECT
  DATE(started_at) as StartDate,
  COUNT(ride_id) as CountOfRows 
FROM bikeshare3
WHERE duration > CAST('0 days 00:00:00' AS INTERVAL)
GROUP BY 1
ORDER BY 1;
'''
df = pd.read_sql_query(q, engine)
df
# Out:
#      startdate  countofrows
# 0   2022-03-01         6927
# 1   2022-03-02         7887
# 2   2022-03-03         7053
# 3   2022-03-04         6717
# 4   2022-03-05         9691
# 5   2022-03-06         9336
# 6   2022-03-07         6650
# 7   2022-03-08         7596
# 8   2022-03-09         3891
# 9   2022-03-10         7576
# 10  2022-03-11         9236
# 11  2022-03-12         2119
# 12  2022-03-13         4311
# 13  2022-03-14         8006
# 14  2022-03-15        10420
# 15  2022-03-16        11053
# 16  2022-03-17         5603
# 17  2022-03-18        11445
# 18  2022-03-19        14024
# 19  2022-03-20         9001
# 20  2022-03-21        11026
# 21  2022-03-22        12740
# 22  2022-03-23         5904
# 23  2022-03-24         7731
# 24  2022-03-25        12665
# 25  2022-03-26        11522
# 26  2022-03-27         5835
# 27  2022-03-28         5004
# 28  2022-03-29         6645
# 29  2022-03-30         8614
# 30  2022-03-31         7987

# %% [markdown]
# #### We can also write the above query like so:

# %%
q ='''SELECT
  CAST(started_at AS DATE) as StartDate,
  COUNT(started_at) as CountOfRows 
FROM bikeshare3
WHERE duration > CAST('0 days 00:00:00' AS INTERVAL)
GROUP BY CAST(started_at AS DATE)
ORDER BY CAST(started_at AS DATE);'''
df =  pd.read_sql_query(q, engine); #Cast to date removes timestamp

# %%
df #count of bike rentals per day
# Out:
#      startdate  countofrows
# 0   2022-03-01         6927
# 1   2022-03-02         7887
# 2   2022-03-03         7053
# 3   2022-03-04         6717
# 4   2022-03-05         9691
# 5   2022-03-06         9336
# 6   2022-03-07         6650
# 7   2022-03-08         7596
# 8   2022-03-09         3891
# 9   2022-03-10         7576
# 10  2022-03-11         9236
# 11  2022-03-12         2119
# 12  2022-03-13         4311
# 13  2022-03-14         8006
# 14  2022-03-15        10420
# 15  2022-03-16        11053
# 16  2022-03-17         5603
# 17  2022-03-18        11445
# 18  2022-03-19        14024
# 19  2022-03-20         9001
# 20  2022-03-21        11026
# 21  2022-03-22        12740
# 22  2022-03-23         5904
# 23  2022-03-24         7731
# 24  2022-03-25        12665
# 25  2022-03-26        11522
# 26  2022-03-27         5835
# 27  2022-03-28         5004
# 28  2022-03-29         6645
# 29  2022-03-30         8614
# 30  2022-03-31         7987

# %% [markdown]
# #### PostgreSQL functions

# %% [markdown]
# CREATE OR REPLACE FUNCTION total_rides()
# DELIMITER // #COMMENT: markdown reads $$ as italics
# RETURNS INTEGER AS /total/
# DECLARE total integer;
# BEGIN
# SELECT COUNT(ride_id) INTO total FROM public.bikeshare3;
# RETURN total;
# END;
# /total/
# LANGUAGE plpgsql;

# %%
pd.read_sql_query('''SELECT total_rides();''', engine)
# Out:
#     total
# 0  254251

# %% [markdown]
# ##### Create a function to return the max duration of the rides in the dataset

# %% [markdown]
# CREATE OR REPLACE FUNCTION max_duration()
# DELIMITER //  #Comment: markdown reads $$ as italics
# RETURNS INTERVAL AS //maxd//
# DECLARE maxd INTERVAL;
# BEGIN
# SELECT MAX(duration) INTO maxd FROM public.bikeshare3;
# RETURN maxd;
# END;
# //maxd//
# LANGUAGE plpgsql;

# %%
pd.read_sql_query('''SELECT max_duration();''', engine)
# Out:
#       max_duration
# 0 16 days 15:24:35
